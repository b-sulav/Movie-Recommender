# %%
import pandas as pd
import ast

movies=pd.read_csv('tmdb_5000_movies.csv')
credits=pd.read_csv('tmdb_5000_credits.csv')
movies=movies.merge(credits, on='title')

def convert_to_list(obj):
    L = []
    for i in ast.literal_eval(obj):
        L.append(i['name']) 
    return L

def fetch_director(obj):
    L = []
    for i in ast.literal_eval(obj):
        if i['job'] == 'Director':
            L.append(i['name'])
            break 
    return L
    
movies.genres = movies.genres.apply(convert_to_list)
movies.keywords = movies.keywords.apply(convert_to_list)
movies['director'] = movies['crew'].apply(fetch_director)
movies=movies[['id','genres','keywords','title','director']]
print(len(movies))
movies.sample(10)
# Out:
# 4809
#           id                               genres  \
# 2148   19904          [Horror, Thriller, Mystery]
# 4240   13066                    [Comedy, Romance]
# 1474  228205                     [Drama, Romance]
# 2317     496                             [Comedy]
# 1775   16617           [Mystery, Thriller, Crime]
# 1984    6478                       [Drama, Music]
# 4426   84178                   [Thriller, Horror]
# 2200   81796  [Action, Thriller, Science Fiction]
# 1980   20697              [Action, Comedy, Drama]
# 1311  256961             [Action, Comedy, Family]
#
#                                                keywords  \
# 2148                              [step father, remake]
# 4240                                 [independent film]
# 1474  [based on novel, art student, cowboy, injury, ...
# 2317  [male nudity, usa, california, prostitute, jou...
# 1775    [fbi, island, serial killer, series of murders]
# 1984       [musical, perfectionist, rowboat, courtship]
# 4426           [friends, remote island, woman director]
# 2200  [usa president, anti hero, dementia, future, s...
# 1980                                 [wrestling, sport]
# 1311         [shopping mall, las vegas, security guard]
#
#                                                   title               director
# 2148                                     The Stepfather     [Nelson McCormick]
# 4240                  I Want Someone to Eat Cheese With          [Jeff Garlin]
# 1474                                   The Longest Ride  [George Tillman, Jr.]
# 2317  Borat: Cultural Learnings of America for Make ...        [Larry Charles]
# 1775                                        Mindhunters         [Renny Harlin]
# 1984                                     Beyond the Sea         [Kevin Spacey]
# 4426                                         Black Rock        [Katie Aselton]
# 2200                                            Lockout    [Stephen St. Leger]
# 1980                                    Ready to Rumble        [Brian Robbins]
# 1311                             Paul Blart: Mall Cop 2         [Andy Fickman]
